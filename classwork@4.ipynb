# %% [markdown]
# ## Importig Data:

# %%
import pandas as pd
df = pd.read_json("C:\\Users\\Venkat Dyagala\\Desktop\\TBA_Class\\TBA\\Arts_Crafts_and_Sewing_5 .json",lines=True)

df.sample(25)
# Out:
#         overall  verified   reviewTime      reviewerID        asin  \
# 217964        5      True  08 14, 2014  A2SXAKNPOH836V  B004V071W0
# 121024        5     False  04 10, 2015   AIQVFRCLY05OI  B001668EL4
# 229289        3      True   06 4, 2015  A2HD0K8WH1GCGK  B0058EDJ2E
# 60473         5      True  05 27, 2015   AE84F997C46PM  B000YZ8N6Y
# 217646        5      True   02 3, 2016   A9RMTXQXFFQAL  B004V071W0
# 72032         5      True   03 4, 2014   AR5I1I90U19CA  B0013V73QE
# 242222        5      True   01 2, 2017  A30GXV8W36C1N4  B005ZHYNJC
# 168679        5      True  10 29, 2015   ANNCOBJ3Q96JI  B0026HR1FC
# 400842        5      True  02 24, 2017  A1S9UQEJQ5PCM0  B01AL8KY88
# 341603        5      True   10 4, 2017  A2UIHS52JLOSW8  B00L5I8RTW
# 222979        5      True  06 11, 2015  A147YUOC1HAMU9  B005025KQC
# 93962         5      True  02 27, 2016  A291DYDDTVEZ84  B000XZTUFS
# 104931        5      True   04 5, 2015  A36FE5HD6XTNG5  B000YZ8SJ6
# 130304        5      True   08 5, 2016  A2NOV4DNGE1IAZ  B0017R9Q5K
# 299785        5      True  08 30, 2014   AEZ8EHPRK19OD  B00DMC6KAC
# 280499        5      True  10 24, 2014  A3IL6R9BW5F9FV  B00B2GK2DG
# 486107        5      True  01 24, 2018  A1N96LPER9EIO8  B010UA3YJ8
# 324308        5      True  10 21, 2014  A39HKHD4XCMXJ9  B00HZM67BM
# 122628        5      True  12 11, 2016  A3ANIAGGBLL251  B001687PNA
# 9078          5      True  11 11, 2015  A3UL5EQ5FKVK2O  B0007XDHG4
# 21019         5      True  04 23, 2015  A1XMDHNC9TG10F  B000FNG29A
# 154142        5      True  08 12, 2015  A1YAPHSDR87XLO  B000WE04KU
# 207494        4      True  10 16, 2016   A3L8YLLU3BSOU  B004B44PYI
# 37885         4      True   12 4, 2017  A3IQ9W5VNFYYFT  B000T67V4S
# 330557        4      True  08 19, 2014   A88D05I216G61  B00J39I2F4
#
#                                                 style  \
# 217964                                            NaN
# 121024  {'Size:': ' 120', 'Color:': ' Antique Brown'}
# 229289                                            NaN
# 60473                            {'Size:': ' 1 Pack'}
# 217646                                            NaN
# 72032                                             NaN
# 242222                           {'Color:': ' Black'}
# 168679                                            NaN
# 400842                           {'Color:': ' Black'}
# 341603                                            NaN
# 222979                                            NaN
# 93962                            {'Color:': ' White'}
# 104931                {'Color:': ' Original Version'}
# 130304                                            NaN
# 299785                                            NaN
# 280499           {'Style Name:': ' Garden Butterfly'}
# 486107                     {'Size:': ' Fit 6mm Cord'}
# 324308                                            NaN
# 122628                           {'Size:': ' 1 Pack'}
# 9078                                              NaN
# 21019                            {'Size:': ' 1-Pack'}
# 154142     {'Color:': ' 100 11"x11" Sheets Cut-away'}
# 207494                                            NaN
# 37885    {'Size:': ' No. 1', 'Style Name:': ' Small'}
# 330557                                {'Size:': ' 1'}
#
#                      reviewerName  \
# 217964                     Debbie
# 121024                   Holly H.
# 229289          Christopher Short
# 60473                   B. Eugene
# 217646                Diane Toney
# 72032   Craddock&#039;s Creations
# 242222                     SMWJTW
# 168679                    Frances
# 400842                PinkJourney
# 341603          patricia zambreno
# 222979         Sherri Lynn Sagers
# 93962                robert busch
# 104931           VICKI COLANTUONO
# 130304                     Burnie
# 299785                     Bobbie
# 280499                        Pam
# 486107            Amazon Customer
# 324308                historybuff
# 122628            Blissful Living
# 9078                 S. Mansfield
# 21019                   lovebooks
# 154142              Alicia Parker
# 207494                          d
# 37885                   WineGrrrl
# 330557                     Wisdom
#
#                                                reviewText  \
# 217964  arrived on time no problems fair price, nice p...
# 121024  I had mine all in a rectangular box, but they ...
# 229289                         Disappointed, cheaply made
# 60473                                           Excellent
# 217646                        Just what I was looking for
# 72032   These trays are great. It helps me to lay out ...
# 242222                Great quality! Will purchase again.
# 168679                             Returned. Did not keep
# 400842              Will certainly order again very soon!
# 341603                                             great!
# 222979                Great - Just as described - Thanks!
# 93962                   ADDS A NICE ADDITION TO A PROJECT
# 104931                                       As described
# 130304                               Accurate and pretty.
# 299785  Highly Recommend! Fast delivery! Exactly as de...
# 280499                                       Works great!
# 486107                These are very nice and strong !!!!
# 324308                          another wonderful product
# 122628  This is a nice size board. It is bigger than t...
# 9078    I paint illustration type watercolors. I most ...
# 21019                                          great book
# 154142  I use this stabilizer a lot for my embroidery ...
# 207494  This works very well. It's not the smoothest, ...
# 37885   Inexpensive and perfect for mixing acrylic pai...
# 330557  It is not quite what I expected as I thought t...
#
#                                                   summary  unixReviewTime  \
# 217964                                       nice product      1407974400
# 121024               Absolutely perfect for crochet hooks      1428624000
# 229289                                          Euro tool      1433376000
# 60473                                          Five Stars      1432684800
# 217646                                         Five Stars      1454457600
# 72032                                             Helpful      1393891200
# 242222                                         Five Stars      1483315200
# 168679                                         Five Stars      1446076800
# 400842                                     Fast Shipping!      1487894400
# 341603                                         Five Stars      1507075200
# 222979                                         Five Stars      1433980800
# 93962                                          Five Stars      1456531200
# 104931                                         Five Stars      1428192000
# 130304                                           Accurate      1470355200
# 299785                                         Five Stars      1409356800
# 280499                                              Punch      1414108800
# 486107                                         Five Stars      1516752000
# 324308                                         Five Stars      1413849600
# 122628                                        Great Value      1481414400
# 9078                                       Fits my needs.      1447200000
# 21019                                          Five Stars      1429747200
# 154142  ... this stabilizer a lot for my embroidery bu...      1439337600
# 207494  but I'm not super serious and don't really hav...      1476576000
# 37885   Inexpensive and perfect for mixing acrylic pai...      1512345600
# 330557                              It gets the job done!      1408406400
#
#        vote                                              image
# 217964  NaN                                                NaN
# 121024    3                                                NaN
# 229289  NaN                                                NaN
# 60473   NaN                                                NaN
# 217646  NaN                                                NaN
# 72032   NaN                                                NaN
# 242222  NaN                                                NaN
# 168679  NaN                                                NaN
# 400842  NaN  [https://images-na.ssl-images-amazon.com/image...
# 341603  NaN                                                NaN
# 222979  NaN                                                NaN
# 93962   NaN                                                NaN
# 104931  NaN                                                NaN
# 130304  NaN                                                NaN
# 299785  NaN                                                NaN
# 280499  NaN                                                NaN
# 486107  NaN                                                NaN
# 324308  NaN                                                NaN
# 122628  NaN                                                NaN
# 9078      8                                                NaN
# 21019   NaN                                                NaN
# 154142  NaN                                                NaN
# 207494  NaN                                                NaN
# 37885   NaN                                                NaN
# 330557  NaN                                                NaN

# %% [markdown]
# ## Bing Liu lexicon:

# %%
from sklearn import preprocessing
import nltk
nltk.download('opinion_lexicon')
from nltk.corpus import opinion_lexicon
from nltk.tokenize import word_tokenize
print('Total number of words in opinion lexicon', len(opinion_lexicon.words()))
print('Examples of positive words in opinion lexicon',opinion_lexicon.positive()[:10])
print('Examples of negative words in opinion lexicon',opinion_lexicon.negative()[:10])
# Out:
# Total number of words in opinion lexicon 6789
# Examples of positive words in opinion lexicon ['a+', 'abound', 'abounds', 'abundance', 'abundant', 'accessable', 'accessible', 'acclaim', 'acclaimed', 'acclamation']
# Examples of negative words in opinion lexicon ['2-faced', '2-faces', 'abnormal', 'abolish', 'abominable', 'abominably', 'abominate', 'abomination', 'abort', 'aborted']
# [nltk_data] Downloading package opinion_lexicon to C:\Users\Venkat
# [nltk_data]     Dyagala\AppData\Roaming\nltk_data...
# [nltk_data]   Package opinion_lexicon is already up-to-date!

# %% [markdown]
# ## Creating a Dictionary

# %%
# Let's create a dictionary which we can use for scoring our review text
nltk.download('punkt')
df.rename(columns={"reviewText": "text"}, inplace=True)
pos_score = 1
neg_score = -1
word_dict = {}
# Adding the positive words to the dictionary
for word in opinion_lexicon.positive():
    word_dict[word] = pos_score

# Adding the negative words to the dictionary
for word in opinion_lexicon.negative():
    word_dict[word] = neg_score
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Venkat
# [nltk_data]     Dyagala\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## calculating score

# %%
def bing_liu_score(text):
    sentiment_score = 0
    bag_of_words = word_tokenize(text.lower())
    for word in bag_of_words:
        if word in word_dict:
            sentiment_score += word_dict[word]
    return sentiment_score

# %%
df['text'].fillna('no review', inplace=True)
df['Bing_Liu_Score'] = df['text'].apply(bing_liu_score)

# %% [markdown]
# ## Visualizing Bing_Liu_Score:

# %%
df[['overall',"text", 'Bing_Liu_Score']].head(10)
# Out:
#    overall                                               text  Bing_Liu_Score
# 0        4                Contains some interesting stitches.               1
# 1        5  I'm a fairly experienced knitter of the one-co...              22
# 2        4  Great book but the index is terrible. Had to w...               0
# 3        5  I purchased the Kindle edition which is incred...               4
# 4        5  Very well laid out and very easy to read.\n\nT...               5
# 5        5  Beginning her career as a freelance knitter, M...              15
# 6        5  This is a terrific stitch handbook (and I have...               9
# 7        4  The book needs to be coil bound. The content i...               1
# 8        5  I really am enjoying this book! I like the siz...              12
# 9        5  Just received this book and looked over it cov...               6

# %%
df.groupby('overall').agg({'Bing_Liu_Score':'mean'})
# Out:
#          Bing_Liu_Score
# overall
# 1             -0.255049
# 2              0.565942
# 3              1.158865
# 4              2.028064
# 5              2.129976
